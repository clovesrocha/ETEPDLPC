# %% [markdown]
# <a href="https://colab.research.google.com/github/clovesrocha/ETEPDLPC/blob/master/LPC1_Fluxo_Dados_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de tela de 2022-03-21 17-31-30.png](data:image/png;base64,...)

# %%
# ETE PORTO DIGITAL
# LPC1 - MÓDULO 1
# PROFESSOR: CLOVES ROCHA
# Parte 1/3 - Listar pessoas

pessoas = [
           {'id':0, 'nome': 'Cloves' },
           {'id':1, 'nome': 'Estudante 1' },
           {'id':2, 'nome': 'Estudante 2' },
           {'id':3, 'nome': 'Estudante 3' },
           {'id':4, 'nome': 'Estudante 4' },
           {'id':5, 'nome': 'Estudante 5' }
  ]
print('Lista das pessoas cadastradas:', pessoas)

# %%
# Parte 2/3 - Inserir pessoas

pessoas = input('Insira o nome de uma pessoa no sistema:')

# %%
# Parte 3/3 - Estrutura de repetição das pessoas cadastradas
#Desafio Aula de Hoje =) 
#- Fazer uma lista vazia que o usuário adicione os dados.
pessoas = ['José', 'Maria', 'Cloves']
for p in pessoas:
  print(p)

# %%
# Resolusão do Professor
pessoas = [ ] #Lista vazia.
for p in range (0, 3):
  print('Pessoa: ', p+1)
  pessoa = input('Digite o nome da pessoa: ')
  pessoas.append({p, pessoa})
 # Imprimi a lista de pessoas cadastrada.
print(pessoas)
# Out:
# Pessoa:  1
# Digite o nome da pessoa: Cloves
# Pessoa:  2
# Digite o nome da pessoa: Alves
# Pessoa:  3
# Digite o nome da pessoa: Rocha
# [{0, 'Cloves'}, {1, 'Alves'}, {2, 'Rocha'}]
